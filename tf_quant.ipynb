# %%
import torch

import random
import numpy as np
import onnx
import onnx_tf

def manual_seed(seed):
    np.random.seed(seed) #1
    random.seed(seed) #2
    torch.manual_seed(seed) #3
    torch.cuda.manual_seed(seed) #4.1
    torch.cuda.manual_seed_all(seed) #4.2
    torch.backends.cudnn.benchmark = False #5 
    torch.backends.cudnn.deterministic = True #6

manual_seed(42)

# %%
filepath = './checkpoint/vgg16.pth'
checkpoint = torch.load(filepath)
# torch_model = vgg.load_vgg16(num_classes= 100)
torch_model = checkpoint['model']
print(torch_model)
torch_model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=100, bias=True)
#   )
# )
# <All keys matched successfully>

# %%
torch_model.eval()
input = torch.randn(1,3,224,224)
print(input.shape, input.dtype)
output = torch_model(input)
print(output.shape)
onnx_path = "./checkpoint/vgg16.onnx"

torch.onnx.export(model= torch_model,               # 실행될 모델
                  args=input,                         # 모델 입력값 (튜플 또는 여러 입력값들도 가능)
                  f= onnx_path,   # 모델 저장 경로 (파일 또는 파일과 유사한 객체 모두 가능)
                  export_params=True,        # 모델 파일 안에 학습된 모델 가중치를 저장할지의 여부
                  verbose=True,
                  input_names = ['inputs'],   # 모델의 입력값을 가리키는 이름
                  output_names = ['outputs'], # 모델의 출력값을 가리키는 이름
                  opset_version = 15,
                  do_constant_folding=True,  # 최적화시 상수폴딩을 사용할지의 여부
)
# Out:
# torch.Size([1, 3, 224, 224]) torch.float32
# torch.Size([1, 512, 7, 7])
# avgpool -> torch.Size([1, 512, 7, 7])
# torch.Size([1, 100])
# torch.Size([1, 512, 7, 7])
# avgpool -> torch.Size([1, 512, 7, 7])
# Exported graph: graph(%inputs : Float(1, 3, 224, 224, strides=[150528, 50176, 224, 1], requires_grad=0, device=cpu),
#       %features.0.weight : Float(64, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.0.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %features.2.weight : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.2.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %features.5.weight : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.5.bias : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %features.7.weight : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.7.bias : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %features.10.weight : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.10.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %features.12.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.12.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %features.14.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.14.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %features.17.weight : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.17.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %features.19.weight : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.19.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %features.21.weight : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.21.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %features.24.weight : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.24.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %features.26.weight : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.26.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %features.28.weight : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %features.28.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %classifier.0.weight : Float(4096, 25088, strides=[25088, 1], requires_grad=1, device=cpu),
#       %classifier.0.bias : Float(4096, strides=[1], requires_grad=1, device=cpu),
#       %classifier.3.weight : Float(4096, 4096, strides=[4096, 1], requires_grad=1, device=cpu),
#       %classifier.3.bias : Float(4096, strides=[1], requires_grad=1, device=cpu),
#       %classifier.6.weight : Float(100, 4096, strides=[4096, 1], requires_grad=1, device=cpu),
#       %classifier.6.bias : Float(100, strides=[1], requires_grad=1, device=cpu)):
#   %/features/features.0/Conv_output_0 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.0/Conv"](%inputs, %features.0.weight, %features.0.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.0 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.1/Relu_output_0 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.1/Relu"](%/features/features.0/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.1 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.2/Conv_output_0 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.2/Conv"](%/features/features.1/Relu_output_0, %features.2.weight, %features.2.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.2 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.3/Relu_output_0 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.3/Relu"](%/features/features.2/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.3 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.4/MaxPool_output_0 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/features/features.4/MaxPool"](%/features/features.3/Relu_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.pooling.MaxPool2d::features.4 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:782:0
#   %/features/features.5/Conv_output_0 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.5/Conv"](%/features/features.4/MaxPool_output_0, %features.5.weight, %features.5.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.5 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.6/Relu_output_0 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.6/Relu"](%/features/features.5/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.6 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.7/Conv_output_0 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.7/Conv"](%/features/features.6/Relu_output_0, %features.7.weight, %features.7.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.7 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.8/Relu_output_0 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.8/Relu"](%/features/features.7/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.8 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.9/MaxPool_output_0 : Float(1, 128, 56, 56, strides=[401408, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/features/features.9/MaxPool"](%/features/features.8/Relu_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.pooling.MaxPool2d::features.9 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:782:0
#   %/features/features.10/Conv_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.10/Conv"](%/features/features.9/MaxPool_output_0, %features.10.weight, %features.10.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.10 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.11/Relu_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.11/Relu"](%/features/features.10/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.11 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.12/Conv_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.12/Conv"](%/features/features.11/Relu_output_0, %features.12.weight, %features.12.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.12 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.13/Relu_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.13/Relu"](%/features/features.12/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.13 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.14/Conv_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.14/Conv"](%/features/features.13/Relu_output_0, %features.14.weight, %features.14.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.14 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.15/Relu_output_0 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.15/Relu"](%/features/features.14/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.15 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.16/MaxPool_output_0 : Float(1, 256, 28, 28, strides=[200704, 784, 28, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/features/features.16/MaxPool"](%/features/features.15/Relu_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.pooling.MaxPool2d::features.16 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:782:0
#   %/features/features.17/Conv_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.17/Conv"](%/features/features.16/MaxPool_output_0, %features.17.weight, %features.17.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.17 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.18/Relu_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.18/Relu"](%/features/features.17/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.18 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.19/Conv_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.19/Conv"](%/features/features.18/Relu_output_0, %features.19.weight, %features.19.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.19 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.20/Relu_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.20/Relu"](%/features/features.19/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.20 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.21/Conv_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.21/Conv"](%/features/features.20/Relu_output_0, %features.21.weight, %features.21.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.21 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.22/Relu_output_0 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.22/Relu"](%/features/features.21/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.22 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.23/MaxPool_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/features/features.23/MaxPool"](%/features/features.22/Relu_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.pooling.MaxPool2d::features.23 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:782:0
#   %/features/features.24/Conv_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.24/Conv"](%/features/features.23/MaxPool_output_0, %features.24.weight, %features.24.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.24 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.25/Relu_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.25/Relu"](%/features/features.24/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.25 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.26/Conv_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.26/Conv"](%/features/features.25/Relu_output_0, %features.26.weight, %features.26.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.26 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.27/Relu_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.27/Relu"](%/features/features.26/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.27 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.28/Conv_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/features/features.28/Conv"](%/features/features.27/Relu_output_0, %features.28.weight, %features.28.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.conv.Conv2d::features.28 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:0
#   %/features/features.29/Relu_output_0 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/features/features.29/Relu"](%/features/features.28/Conv_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.activation.ReLU::features.29 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/features/features.30/MaxPool_output_0 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/features/features.30/MaxPool"](%/features/features.29/Relu_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::features/torch.nn.modules.pooling.MaxPool2d::features.30 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:782:0
#   %/avgpool/AveragePool_output_0 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[1, 1], strides=[1, 1], onnx_name="/avgpool/AveragePool"](%/features/features.30/MaxPool_output_0), scope: models.vgg.VGG::/torch.nn.modules.pooling.AdaptiveAvgPool2d::avgpool # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1214:0
#   %/Flatten_output_0 : Float(1, 25088, strides=[25088, 1], requires_grad=1, device=cpu) = onnx::Flatten[axis=1, onnx_name="/Flatten"](%/avgpool/AveragePool_output_0), scope: models.vgg.VGG:: # /workspace/int_infer/models/vgg.py:44:0
#   %/classifier/classifier.0/Gemm_output_0 : Float(1, 4096, strides=[4096, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/classifier/classifier.0/Gemm"](%/Flatten_output_0, %classifier.0.weight, %classifier.0.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::classifier/torch.nn.modules.linear.Linear::classifier.0 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114:0
#   %/classifier/classifier.1/Relu_output_0 : Float(1, 4096, strides=[4096, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/classifier/classifier.1/Relu"](%/classifier/classifier.0/Gemm_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::classifier/torch.nn.modules.activation.ReLU::classifier.1 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %/classifier/classifier.3/Gemm_output_0 : Float(1, 4096, strides=[4096, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/classifier/classifier.3/Gemm"](%/classifier/classifier.1/Relu_output_0, %classifier.3.weight, %classifier.3.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::classifier/torch.nn.modules.linear.Linear::classifier.3 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114:0
#   %/classifier/classifier.4/Relu_output_0 : Float(1, 4096, strides=[4096, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/classifier/classifier.4/Relu"](%/classifier/classifier.3/Gemm_output_0), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::classifier/torch.nn.modules.activation.ReLU::classifier.4 # /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1455:0
#   %outputs : Float(1, 100, strides=[100, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/classifier/classifier.6/Gemm"](%/classifier/classifier.4/Relu_output_0, %classifier.6.weight, %classifier.6.bias), scope: models.vgg.VGG::/torch.nn.modules.container.Sequential::classifier/torch.nn.modules.linear.Linear::classifier.6 # /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114:0
#   return (%outputs)
#
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
# load onnx model
onnx_model = onnx.load(onnx_path)

# convet onnx model to tensorflow
tf_model = onnx_tf.backend.prepare(onnx_model)
tf_model_path = "./checkpoint/vgg16.pb"
tf_model.export_graph(tf_model_path)
